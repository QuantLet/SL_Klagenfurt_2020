# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import matplotlib.pyplot as plt

# %%
import os

# %%
d=os.path.dirname(Corona.txt) if "Corona.txt" in locals() else os.getcwd()

# %%
with open("/Users/chiara/Dropbox/UNI/MASTER/Second_Semester/Corona_Project/Corona.txt") as f: 
    text=f.read()

# %%
nichtinteressant= "und der die das von im es mit sind wie bei sie ist einem oder ich kann ein habe wenn auf auch zu den sich wird wurde e4rz au wurden werden eine zur war durch vor vom bereits ebenfalls aus als zum bis diese nach nicht des "

# %%
liste_der_unerwuenschten_woerter = nichtinteressant.split()

# %%
STOPWORDS.update(liste_der_unerwuenschten_woerter)

# %%
wordcloud=WordCloud(background_color="ghostwhite", width=1920, height=1080).generate(text)

# %%
plt.imshow(wordcloud, interpolation="bilinear")

# %%
plt.axis("off")
plt.show()

# %%
plt.show()
